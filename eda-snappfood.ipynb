# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/font-bnazanin/B-NAZANIN.TTF
# /kaggle/input/snappfood/dev.csv
# /kaggle/input/snappfood/train.csv
# /kaggle/input/snappfood/test.csv

# %%
# !pip3 install hazm
# !pip3 install nltk
# Out:
# Requirement already satisfied: hazm in /opt/conda/lib/python3.10/site-packages (0.9.4)
# Requirement already satisfied: fasttext-wheel<0.10.0,>=0.9.2 in /opt/conda/lib/python3.10/site-packages (from hazm) (0.9.2)
# Requirement already satisfied: flashtext<3.0,>=2.7 in /opt/conda/lib/python3.10/site-packages (from hazm) (2.7)
# Requirement already satisfied: gensim<5.0.0,>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from hazm) (4.3.2)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/conda/lib/python3.10/site-packages (from hazm) (3.8.1)
# Requirement already satisfied: numpy==1.24.3 in /opt/conda/lib/python3.10/site-packages (from hazm) (1.24.3)
# Requirement already satisfied: python-crfsuite<0.10.0,>=0.9.9 in /opt/conda/lib/python3.10/site-packages (from hazm) (0.9.10)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.2 in /opt/conda/lib/python3.10/site-packages (from hazm) (1.2.2)
# Requirement already satisfied: pybind11>=2.2 in /opt/conda/lib/python3.10/site-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (2.11.1)
# Requirement already satisfied: setuptools>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (68.1.2)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim<5.0.0,>=4.3.1->hazm) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim<5.0.0,>=4.3.1->hazm) (6.3.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (2023.8.8)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->hazm) (4.66.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2.0.0,>=1.2.2->hazm) (3.2.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
import re
import nltk
from hazm import stopwords_list
from itertools import chain
from collections import Counter
import plotly.express as px

# %%
sns.set_style('whitegrid')
plt.set_cmap('Set2')
sns.set_palette('Set2')

# %%
train_df = pd.read_csv('/kaggle/input/snappfood/train.csv', delimiter='\t', on_bad_lines='skip',  usecols=[1, 2, 3])
test_df = pd.read_csv('/kaggle/input/snappfood/test.csv', delimiter='\t', on_bad_lines='skip',  usecols=[1, 2, 3])
dev_df = pd.read_csv('/kaggle/input/snappfood/dev.csv', delimiter='\t', on_bad_lines='skip',  usecols=[1, 2, 3])

# %%
print(f"Train Shape: {train_df.shape}")
print(f"Test Shape: {test_df.shape}")
print(f"Dev Shape: {dev_df.shape}")
# Out:
# Train Shape: (56700, 3)
# Test Shape: (7000, 3)
# Dev Shape: (6300, 3)

# %%
train_df.head()
# Out:
#                                              comment  label  label_id
# 0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح    SAD         1
# 1  قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...  HAPPY         0
# 2  قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...    SAD         1
# 3  عالللی بود همه چه درست و به اندازه و کیفیت خوب...  HAPPY         0
# 4                      شیرینی وانیلی فقط یک مدل بود.  HAPPY         0

# %%
train_df.columns
# Out:
# Index(['comment', 'label', 'label_id'], dtype='object')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56700 entries, 0 to 56699
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   comment   56700 non-null  object
#  1   label     56700 non-null  object
#  2   label_id  56700 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.3+ MB

# %%
train_df.describe()
# Out:
#            label_id
# count  56700.000000
# mean       0.500000
# std        0.500004
# min        0.000000
# 25%        0.000000
# 50%        0.500000
# 75%        1.000000
# max        1.000000

# %%
train_df.isna().sum()
# Out:
# comment     0
# label       0
# label_id    0
# dtype: int64

# %%
train_df.drop_duplicates(subset='comment', inplace=True)

# %%
datasets = {'Train': train_df, 'Dev': dev_df, 'Test': test_df}

# %%
def plot_label_distribution(df, dataset_type, ax):
    sns.countplot(x='label', data=df, ax=ax)
    ax.set_title(f"{dataset_type} dataset")
    ax.set_xlabel('Label')  
    ax.set_ylabel('Count')

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 6))

for ax, (title, df) in zip(axes, datasets.items()):
    plot_label_distribution(df, title, ax)

fig.suptitle("Distribution of Labels")
plt.tight_layout()
plt.show()

# %%
def plot_label_pie_chart(df, dataset_type, ax):
    labels = df['label'].value_counts()
    ax.pie(labels, labels=labels.index, autopct='%.f%%')
    ax.set_title(f"{dataset_type} dataset")

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 6))

for ax, (dataset_type, df) in zip(axes, datasets.items()):
    plot_label_pie_chart(df, dataset_type, ax)

fig.suptitle("Proportions of Target Classes")
plt.show()

# %%
train_df['cleaned_comment'] = train_df['comment'].apply(lambda x: re.sub(r'[^\w\s\u0600-\u06FF]', '', x))
train_df['tokens'] = train_df['cleaned_comment'].apply(word_tokenize)
train_df.head()
# Out:
#                                              comment  label  label_id  \
# 0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح    SAD         1
# 1  قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...  HAPPY         0
# 2  قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...    SAD         1
# 3  عالللی بود همه چه درست و به اندازه و کیفیت خوب...  HAPPY         0
# 4                      شیرینی وانیلی فقط یک مدل بود.  HAPPY         0
#
#                                      cleaned_comment  \
# 0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح
# 1  قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...
# 2  قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...
# 3  عالللی بود همه چه درست و به اندازه و کیفیت خوب...
# 4                       شیرینی وانیلی فقط یک مدل بود
#
#                                               tokens
# 0  [واقعا, حیف, وقت, که, بنویسم, سرویس, دهیتون, ش...
# 1  [قرار, بود, ۱, ساعته, برسه, ولی, نیم, ساعت, زو...
# 2  [قیمت, این, مدل, اصلا, با, کیفیتش, سازگاری, ند...
# 3  [عالللی, بود, همه, چه, درست, و, به, اندازه, و,...
# 4                [شیرینی, وانیلی, فقط, یک, مدل, بود]

# %%
# Set of Persian stop words using hazm
stop_words = set(stopwords_list())
print(list(stop_words)[:20])
# Out:
# ['سالهای', 'آخرین', 'شده_اند', 'قبل', 'می\u200cدهد', 'دیگری', 'سپس', 'دیگران', 'وارد', 'می\u200cدهند', 'ولی', 'عدم', 'می\u200cتوان', 'شدن', 'می\u200cگوید', 'بدون', 'علت', 'را', 'دسته', 'چیزی']

# %%
train_df['tokens'] = train_df['tokens'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
persian_font = '/kaggle/input/font-bnazanin/B-NAZANIN.TTF'
combined_text = " ".join(comment for comment in train_df['cleaned_comment'])

# Generate the word cloud considering Persian specifics
wordcloud = WordCloud(
    font_path=persian_font,
    width=800,
    height=400,
    background_color="white",
    colormap='Dark2',
    stopwords=stop_words
).generate(combined_text)

plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Words cloud', fontsize=24)
plt.show()

# %%
persian_font = '/kaggle/input/font-bnazanin/B-NAZANIN.TTF'
combined_text = " ".join(comment for comment in train_df[train_df['label'] == "HAPPY"]['cleaned_comment'])

# Generate the word cloud considering Persian specifics
wordcloud = WordCloud(
    font_path=persian_font,
    width=800,
    height=400,
    background_color="white",
    colormap='Dark2',
    stopwords=stop_words
).generate(combined_text)

plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Words cloud for happy comments', fontsize=24)
plt.show()

# %%
persian_font = '/kaggle/input/font-bnazanin/B-NAZANIN.TTF'
combined_text = " ".join(comment for comment in train_df[train_df['label'] == "SAD"]['cleaned_comment'])

# Generate the word cloud considering Persian specifics
wordcloud = WordCloud(
    font_path=persian_font,
    width=800,
    height=400,
    background_color="white",
    colormap='Dark2',
    stopwords=stop_words
).generate(combined_text)

plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Words cloud for sad comments', fontsize=24)
plt.show()

# %%
train_df['comment_length'] = train_df['cleaned_comment'].apply(len)

# %%
train_df.head()
# Out:
#                                              comment  label  label_id  \
# 0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح    SAD         1
# 1  قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...  HAPPY         0
# 2  قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...    SAD         1
# 3  عالللی بود همه چه درست و به اندازه و کیفیت خوب...  HAPPY         0
# 4                      شیرینی وانیلی فقط یک مدل بود.  HAPPY         0
#
#                                      cleaned_comment  \
# 0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح
# 1  قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...
# 2  قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...
# 3  عالللی بود همه چه درست و به اندازه و کیفیت خوب...
# 4                       شیرینی وانیلی فقط یک مدل بود
#
#                                               tokens  comment_length
# 0   [واقعا, حیف, وقت, بنویسم, سرویس, دهیتون, افتضاح]              47
# 1  [قرار, ۱, ساعته, برسه, نیم, ساعت, زودتر, موقع,...             146
# 2  [قیمت, مدل, اصلا, کیفیتش, سازگاری, نداره،, ظاه...              89
# 3  [عالللی, درست, اندازه, کیفیت, خوب،, امیداورم, ...             101
# 4                              [شیرینی, وانیلی, مدل]              28

# %%
plt.subplot(1,2,1)

sns.boxplot(y=train_df['comment_length'], hue=train_df['label'])
plt.ylabel('Comment length', labelpad=12.5)

plt.subplot(1,2,2)
sns.kdeplot(data=train_df, x='comment_length', hue='label', common_norm=False)
plt.legend(train_df['label'].unique())
plt.xlabel('')
plt.ylabel('')

plt.show()

# %%
print(f"Mean length of happy comments: {train_df[train_df['label'] == 'HAPPY']['comment_length'].mean()}")
print(f"Mean length of sad comments: {train_df[train_df['label'] == 'SAD']['comment_length'].mean()}")
# Out:
# Mean length of happy comments: 75.90924162257495
# Mean length of sad comments: 100.58514991181657

# %%
train_df['word_count'] = train_df['cleaned_comment'].apply(lambda x:len(str(x).split()))

# %%
train_df.head()
# Out:
#                                              comment  label  label_id  \
# 0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح    SAD         1
# 1  قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...  HAPPY         0
# 2  قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...    SAD         1
# 3  عالللی بود همه چه درست و به اندازه و کیفیت خوب...  HAPPY         0
# 4                      شیرینی وانیلی فقط یک مدل بود.  HAPPY         0
#
#                                      cleaned_comment  \
# 0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح
# 1  قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...
# 2  قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...
# 3  عالللی بود همه چه درست و به اندازه و کیفیت خوب...
# 4                       شیرینی وانیلی فقط یک مدل بود
#
#                                               tokens  comment_length  \
# 0   [واقعا, حیف, وقت, بنویسم, سرویس, دهیتون, افتضاح]              47
# 1  [قرار, ۱, ساعته, برسه, نیم, ساعت, زودتر, موقع,...             146
# 2  [قیمت, مدل, اصلا, کیفیتش, سازگاری, نداره،, ظاه...              89
# 3  [عالللی, درست, اندازه, کیفیت, خوب،, امیداورم, ...             101
# 4                              [شیرینی, وانیلی, مدل]              28
#
#    word_count
# 0           9
# 1          26
# 2          17
# 3          20
# 4           6

# %%
plt.subplot(1,2,1)

sns.boxplot(y=train_df['word_count'], hue=train_df['label'])
plt.ylabel('Word count', labelpad=12.5)

plt.subplot(1,2,2)
sns.kdeplot(data=train_df, x='word_count', hue='label', common_norm=False)
plt.legend(train_df['label'].unique())
plt.xlabel('')
plt.ylabel('')

plt.show()

# %%
print(f"Mean word count for happy comments: {train_df[train_df['label'] == 'HAPPY']['word_count'].mean()}")
print(f"Mean word count for sad comments: {train_df[train_df['label'] == 'SAD']['word_count'].mean()}")
# Out:
# Mean word count for happy comments: 15.972627865961199
# Mean word count for sad comments: 21.123527336860672

# %%
all_words = [word for tokens_list in train_df['tokens'] for word in tokens_list]

word_counter = Counter(all_words)
most_common_words = word_counter.most_common()

# Print the 20 most common words
common_words = pd.DataFrame(most_common_words[:20])
common_words.columns = ['common_words','count']
common_words.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_d013c_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d013c_row1_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_d013c_row2_col1 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_d013c_row3_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_d013c_row4_col1 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_d013c_row5_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_d013c_row6_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_d013c_row7_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_d013c_row8_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_d013c_row9_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_d013c_row10_col1 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_d013c_row11_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_d013c_row12_col1, #T_d013c_row13_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_d013c_row14_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_d013c_row15_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_d013c_row16_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_d013c_row17_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_d013c_row18_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_d013c_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_d013c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d013c_level0_col0" class="col_heading level0 col0" >common_words</th>
#       <th id="T_d013c_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d013c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d013c_row0_col0" class="data row0 col0" >غذا</td>
#       <td id="T_d013c_row0_col1" class="data row0 col1" >12397</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d013c_row1_col0" class="data row1 col0" >کیفیت</td>
#       <td id="T_d013c_row1_col1" class="data row1 col1" >11342</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d013c_row2_col0" class="data row2 col0" >سفارش</td>
#       <td id="T_d013c_row2_col1" class="data row2 col1" >9142</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d013c_row3_col0" class="data row3 col0" >پیتزا</td>
#       <td id="T_d013c_row3_col1" class="data row3 col1" >6259</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d013c_row4_col0" class="data row4 col0" >واقعا</td>
#       <td id="T_d013c_row4_col1" class="data row4 col1" >5671</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d013c_row5_col0" class="data row5 col0" >اصلا</td>
#       <td id="T_d013c_row5_col1" class="data row5 col1" >5407</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d013c_row6_col0" class="data row6 col0" >سرد</td>
#       <td id="T_d013c_row6_col1" class="data row6 col1" >5338</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d013c_row7_col0" class="data row7 col0" >خوشمزه</td>
#       <td id="T_d013c_row7_col1" class="data row7 col1" >4641</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d013c_row8_col0" class="data row8 col0" >ارسال</td>
#       <td id="T_d013c_row8_col1" class="data row8 col1" >4546</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d013c_row9_col0" class="data row9 col0" >طعم</td>
#       <td id="T_d013c_row9_col1" class="data row9 col1" >4127</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d013c_row10_col0" class="data row10 col0" >ممنون</td>
#       <td id="T_d013c_row10_col1" class="data row10 col1" >4038</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d013c_row11_col0" class="data row11 col0" >مرغ</td>
#       <td id="T_d013c_row11_col1" class="data row11 col1" >3920</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d013c_row12_col0" class="data row12 col0" >بد</td>
#       <td id="T_d013c_row12_col1" class="data row12 col1" >3845</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d013c_row13_col0" class="data row13 col0" >تازه</td>
#       <td id="T_d013c_row13_col1" class="data row13 col1" >3821</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d013c_row14_col0" class="data row14 col0" >پیک</td>
#       <td id="T_d013c_row14_col1" class="data row14 col1" >3784</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d013c_row15_col0" class="data row15 col0" >یه</td>
#       <td id="T_d013c_row15_col1" class="data row15 col1" >3694</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d013c_row16_col0" class="data row16 col0" >بود،</td>
#       <td id="T_d013c_row16_col1" class="data row16 col1" >3450</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d013c_row17_col0" class="data row17 col0" >سیب</td>
#       <td id="T_d013c_row17_col1" class="data row17 col1" >3370</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d013c_row18_col0" class="data row18 col0" >بودم</td>
#       <td id="T_d013c_row18_col1" class="data row18 col1" >3306</td>
#     </tr>
#     <tr>
#       <th id="T_d013c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d013c_row19_col0" class="data row19 col0" >تحویل</td>
#       <td id="T_d013c_row19_col1" class="data row19 col1" >3166</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(common_words, x="count", y="common_words", title='Top 20 most Commmon Words', orientation='h', 
             width=700, height=700,color='common_words')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="0c2f645b-968c-444a-98ee-83b851a50f48" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c2f645b-968c-444a-98ee-83b851a50f48")) {                    Plotly.newPlot(                        "0c2f645b-968c-444a-98ee-83b851a50f48",                        [{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"غذا","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"غذا","offsetgroup":"غذا","orientation":"h","showlegend":true,"textposition":"auto","x":[12397],"xaxis":"x","y":["غذا"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"کیفیت","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"کیفیت","offsetgroup":"کیفیت","orientation":"h","showlegend":true,"textposition":"auto","x":[11342],"xaxis":"x","y":["کیفیت"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"سفارش","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"سفارش","offsetgroup":"سفارش","orientation":"h","showlegend":true,"textposition":"auto","x":[9142],"xaxis":"x","y":["سفارش"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"پیتزا","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"پیتزا","offsetgroup":"پیتزا","orientation":"h","showlegend":true,"textposition":"auto","x":[6259],"xaxis":"x","y":["پیتزا"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"واقعا","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"واقعا","offsetgroup":"واقعا","orientation":"h","showlegend":true,"textposition":"auto","x":[5671],"xaxis":"x","y":["واقعا"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"اصلا","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"اصلا","offsetgroup":"اصلا","orientation":"h","showlegend":true,"textposition":"auto","x":[5407],"xaxis":"x","y":["اصلا"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"سرد","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"سرد","offsetgroup":"سرد","orientation":"h","showlegend":true,"textposition":"auto","x":[5338],"xaxis":"x","y":["سرد"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"خوشمزه","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"خوشمزه","offsetgroup":"خوشمزه","orientation":"h","showlegend":true,"textposition":"auto","x":[4641],"xaxis":"x","y":["خوشمزه"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ارسال","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"ارسال","offsetgroup":"ارسال","orientation":"h","showlegend":true,"textposition":"auto","x":[4546],"xaxis":"x","y":["ارسال"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"طعم","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"طعم","offsetgroup":"طعم","orientation":"h","showlegend":true,"te ...

# %%
fig = px.treemap(common_words, path=['common_words'], values='count',title='Tree of Most Common Words')
fig.show()
# Out:
# <div>                            <div id="08a5ba74-ccca-4624-9084-b2b9206d27b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08a5ba74-ccca-4624-9084-b2b9206d27b0")) {                    Plotly.newPlot(                        "08a5ba74-ccca-4624-9084-b2b9206d27b0",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["ارسال","اصلا","بد","بود،","بودم","تازه","تحویل","خوشمزه","سرد","سفارش","سیب","طعم","غذا","مرغ","ممنون","واقعا","پیتزا","پیک","کیفیت","یه"],"labels":["ارسال","اصلا","بد","بود،","بودم","تازه","تحویل","خوشمزه","سرد","سفارش","سیب","طعم","غذا","مرغ","ممنون","واقعا","پیتزا","پیک","کیفیت","یه"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[4546,5407,3845,3450,3306,3821,3166,4641,5338,9142,3370,4127,12397,3920,4038,5671,6259,3784,11342,3694],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker ...

# %%
all_words = [word for tokens_list in train_df[train_df['label'] == 'HAPPY']['tokens'] for word in tokens_list]

word_counter = Counter(all_words)
most_common_words = word_counter.most_common()

# Print the 20 most common words in happy comments
common_happy_words = pd.DataFrame(most_common_words[:20])
common_happy_words.columns = ['common_words','count']
common_happy_words.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_a791c_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a791c_row1_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_a791c_row2_col1 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_a791c_row3_col1 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_a791c_row4_col1 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_a791c_row5_col1 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_a791c_row6_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_a791c_row7_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_a791c_row8_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_a791c_row9_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_a791c_row10_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_a791c_row11_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_a791c_row12_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_a791c_row13_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_a791c_row14_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_a791c_row15_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_a791c_row16_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_a791c_row17_col1, #T_a791c_row18_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_a791c_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_a791c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a791c_level0_col0" class="col_heading level0 col0" >common_words</th>
#       <th id="T_a791c_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a791c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a791c_row0_col0" class="data row0 col0" >غذا</td>
#       <td id="T_a791c_row0_col1" class="data row0 col1" >5058</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a791c_row1_col0" class="data row1 col0" >کیفیت</td>
#       <td id="T_a791c_row1_col1" class="data row1 col1" >4963</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a791c_row2_col0" class="data row2 col0" >خوشمزه</td>
#       <td id="T_a791c_row2_col1" class="data row2 col1" >4059</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a791c_row3_col0" class="data row3 col0" >ممنون</td>
#       <td id="T_a791c_row3_col1" class="data row3 col1" >3742</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a791c_row4_col0" class="data row4 col0" >سفارش</td>
#       <td id="T_a791c_row4_col1" class="data row4 col1" >2841</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a791c_row5_col0" class="data row5 col0" >تازه</td>
#       <td id="T_a791c_row5_col1" class="data row5 col1" >2511</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a791c_row6_col0" class="data row6 col0" >واقعا</td>
#       <td id="T_a791c_row6_col1" class="data row6 col1" >2314</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a791c_row7_col0" class="data row7 col0" >پیتزا</td>
#       <td id="T_a791c_row7_col1" class="data row7 col1" >2262</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a791c_row8_col0" class="data row8 col0" >طعم</td>
#       <td id="T_a791c_row8_col1" class="data row8 col1" >2229</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a791c_row9_col0" class="data row9 col0" >پیک</td>
#       <td id="T_a791c_row9_col1" class="data row9 col1" >2154</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a791c_row10_col0" class="data row10 col0" >گرم</td>
#       <td id="T_a791c_row10_col1" class="data row10 col1" >1982</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a791c_row11_col0" class="data row11 col0" >ارسال</td>
#       <td id="T_a791c_row11_col1" class="data row11 col1" >1969</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a791c_row12_col0" class="data row12 col0" >سریع</td>
#       <td id="T_a791c_row12_col1" class="data row12 col1" >1906</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a791c_row13_col0" class="data row13 col0" >بود،</td>
#       <td id="T_a791c_row13_col1" class="data row13 col1" >1747</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a791c_row14_col0" class="data row14 col0" >موقع</td>
#       <td id="T_a791c_row14_col1" class="data row14 col1" >1542</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a791c_row15_col0" class="data row15 col0" >یه</td>
#       <td id="T_a791c_row15_col1" class="data row15 col1" >1523</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a791c_row16_col0" class="data row16 col0" >بسته</td>
#       <td id="T_a791c_row16_col1" class="data row16 col1" >1495</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a791c_row17_col0" class="data row17 col0" >اسنپ</td>
#       <td id="T_a791c_row17_col1" class="data row17 col1" >1360</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a791c_row18_col0" class="data row18 col0" >بودم</td>
#       <td id="T_a791c_row18_col1" class="data row18 col1" >1357</td>
#     </tr>
#     <tr>
#       <th id="T_a791c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a791c_row19_col0" class="data row19 col0" >سیب</td>
#       <td id="T_a791c_row19_col1" class="data row19 col1" >1321</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(common_happy_words, x="count", y="common_words", title='Top 20 most Commmon Words in happy comments', orientation='h', 
             width=700, height=700,color='common_words')
fig.show()
# Out:
# <div>                            <div id="b4ae8538-9efc-4dbc-84f1-604727b3922d" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4ae8538-9efc-4dbc-84f1-604727b3922d")) {                    Plotly.newPlot(                        "b4ae8538-9efc-4dbc-84f1-604727b3922d",                        [{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"غذا","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"غذا","offsetgroup":"غذا","orientation":"h","showlegend":true,"textposition":"auto","x":[5058],"xaxis":"x","y":["غذا"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"کیفیت","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"کیفیت","offsetgroup":"کیفیت","orientation":"h","showlegend":true,"textposition":"auto","x":[4963],"xaxis":"x","y":["کیفیت"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"خوشمزه","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"خوشمزه","offsetgroup":"خوشمزه","orientation":"h","showlegend":true,"textposition":"auto","x":[4059],"xaxis":"x","y":["خوشمزه"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ممنون","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ممنون","offsetgroup":"ممنون","orientation":"h","showlegend":true,"textposition":"auto","x":[3742],"xaxis":"x","y":["ممنون"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"سفارش","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"سفارش","offsetgroup":"سفارش","orientation":"h","showlegend":true,"textposition":"auto","x":[2841],"xaxis":"x","y":["سفارش"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"تازه","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"تازه","offsetgroup":"تازه","orientation":"h","showlegend":true,"textposition":"auto","x":[2511],"xaxis":"x","y":["تازه"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"واقعا","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"واقعا","offsetgroup":"واقعا","orientation":"h","showlegend":true,"textposition":"auto","x":[2314],"xaxis":"x","y":["واقعا"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"پیتزا","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"پیتزا","offsetgroup":"پیتزا","orientation":"h","showlegend":true,"textposition":"auto","x":[2262],"xaxis":"x","y":["پیتزا"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"طعم","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"طعم","offsetgroup":"طعم","orientation":"h","showlegend":true,"textposition":"auto","x":[2229],"xaxis":"x","y":["طعم"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"پیک","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"پیک","offsetgroup":"پیک","orientation":"h","showlegend":true,"text ...

# %%
fig = px.treemap(common_happy_words, path=['common_words'], values='count',title='Tree of Most Common Words in happy comments')
fig.show()
# Out:
# <div>                            <div id="1f43f381-88f9-43e2-9679-a9ef6551615d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f43f381-88f9-43e2-9679-a9ef6551615d")) {                    Plotly.newPlot(                        "1f43f381-88f9-43e2-9679-a9ef6551615d",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["ارسال","اسنپ","بسته","بود،","بودم","تازه","خوشمزه","سریع","سفارش","سیب","طعم","غذا","ممنون","موقع","واقعا","پیتزا","پیک","کیفیت","گرم","یه"],"labels":["ارسال","اسنپ","بسته","بود،","بودم","تازه","خوشمزه","سریع","سفارش","سیب","طعم","غذا","ممنون","موقع","واقعا","پیتزا","پیک","کیفیت","گرم","یه"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[1969,1360,1495,1747,1357,2511,4059,1906,2841,1321,2229,5058,3742,1542,2314,2262,2154,4963,1982,1523],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","mark ...

# %%
all_words = [word for tokens_list in train_df[train_df['label'] == 'SAD']['tokens'] for word in tokens_list]

word_counter = Counter(all_words)
most_common_words = word_counter.most_common()

# Print the 20 most common words in sad comments
common_sad_words = pd.DataFrame(most_common_words[:20])
common_sad_words.columns = ['common_words','count']
common_sad_words.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_129c3_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_129c3_row1_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_129c3_row2_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_129c3_row3_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_129c3_row4_col1 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_129c3_row5_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_129c3_row6_col1 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_129c3_row7_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_129c3_row8_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_129c3_row9_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_129c3_row10_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_129c3_row11_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_129c3_row12_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_129c3_row13_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_129c3_row14_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_129c3_row15_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_129c3_row16_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_129c3_row17_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_129c3_row18_col1, #T_129c3_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_129c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_129c3_level0_col0" class="col_heading level0 col0" >common_words</th>
#       <th id="T_129c3_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_129c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_129c3_row0_col0" class="data row0 col0" >غذا</td>
#       <td id="T_129c3_row0_col1" class="data row0 col1" >7339</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_129c3_row1_col0" class="data row1 col0" >کیفیت</td>
#       <td id="T_129c3_row1_col1" class="data row1 col1" >6379</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_129c3_row2_col0" class="data row2 col0" >سفارش</td>
#       <td id="T_129c3_row2_col1" class="data row2 col1" >6301</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_129c3_row3_col0" class="data row3 col0" >اصلا</td>
#       <td id="T_129c3_row3_col1" class="data row3 col1" >4628</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_129c3_row4_col0" class="data row4 col0" >سرد</td>
#       <td id="T_129c3_row4_col1" class="data row4 col1" >4056</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_129c3_row5_col0" class="data row5 col0" >پیتزا</td>
#       <td id="T_129c3_row5_col1" class="data row5 col1" >3997</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_129c3_row6_col0" class="data row6 col0" >واقعا</td>
#       <td id="T_129c3_row6_col1" class="data row6 col1" >3357</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_129c3_row7_col0" class="data row7 col0" >بد</td>
#       <td id="T_129c3_row7_col1" class="data row7 col1" >3326</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_129c3_row8_col0" class="data row8 col0" >مرغ</td>
#       <td id="T_129c3_row8_col1" class="data row8 col1" >2745</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_129c3_row9_col0" class="data row9 col0" >ارسال</td>
#       <td id="T_129c3_row9_col1" class="data row9 col1" >2577</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_129c3_row10_col0" class="data row10 col0" >نداشت</td>
#       <td id="T_129c3_row10_col1" class="data row10 col1" >2199</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_129c3_row11_col0" class="data row11 col0" >یه</td>
#       <td id="T_129c3_row11_col1" class="data row11 col1" >2171</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_129c3_row12_col0" class="data row12 col0" >مزه</td>
#       <td id="T_129c3_row12_col1" class="data row12 col1" >2098</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_129c3_row13_col0" class="data row13 col0" >تحویل</td>
#       <td id="T_129c3_row13_col1" class="data row13 col1" >2070</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_129c3_row14_col0" class="data row14 col0" >سیب</td>
#       <td id="T_129c3_row14_col1" class="data row14 col1" >2049</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_129c3_row15_col0" class="data row15 col0" >بودم</td>
#       <td id="T_129c3_row15_col1" class="data row15 col1" >1949</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_129c3_row16_col0" class="data row16 col0" >طعم</td>
#       <td id="T_129c3_row16_col1" class="data row16 col1" >1898</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_129c3_row17_col0" class="data row17 col0" >پایین</td>
#       <td id="T_129c3_row17_col1" class="data row17 col1" >1839</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_129c3_row18_col0" class="data row18 col0" >ساعت</td>
#       <td id="T_129c3_row18_col1" class="data row18 col1" >1740</td>
#     </tr>
#     <tr>
#       <th id="T_129c3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_129c3_row19_col0" class="data row19 col0" >قیمت</td>
#       <td id="T_129c3_row19_col1" class="data row19 col1" >1724</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(common_sad_words, x="count", y="common_words", title='Top 20 most Commmon Words in sad comments', orientation='h', 
             width=700, height=700,color='common_words')
fig.show()
# Out:
# <div>                            <div id="052fafd8-0563-4e0f-8955-1f8915bceb99" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("052fafd8-0563-4e0f-8955-1f8915bceb99")) {                    Plotly.newPlot(                        "052fafd8-0563-4e0f-8955-1f8915bceb99",                        [{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"غذا","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"غذا","offsetgroup":"غذا","orientation":"h","showlegend":true,"textposition":"auto","x":[7339],"xaxis":"x","y":["غذا"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"کیفیت","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"کیفیت","offsetgroup":"کیفیت","orientation":"h","showlegend":true,"textposition":"auto","x":[6379],"xaxis":"x","y":["کیفیت"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"سفارش","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"سفارش","offsetgroup":"سفارش","orientation":"h","showlegend":true,"textposition":"auto","x":[6301],"xaxis":"x","y":["سفارش"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"اصلا","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"اصلا","offsetgroup":"اصلا","orientation":"h","showlegend":true,"textposition":"auto","x":[4628],"xaxis":"x","y":["اصلا"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"سرد","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"سرد","offsetgroup":"سرد","orientation":"h","showlegend":true,"textposition":"auto","x":[4056],"xaxis":"x","y":["سرد"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"پیتزا","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"پیتزا","offsetgroup":"پیتزا","orientation":"h","showlegend":true,"textposition":"auto","x":[3997],"xaxis":"x","y":["پیتزا"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"واقعا","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"واقعا","offsetgroup":"واقعا","orientation":"h","showlegend":true,"textposition":"auto","x":[3357],"xaxis":"x","y":["واقعا"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"بد","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"بد","offsetgroup":"بد","orientation":"h","showlegend":true,"textposition":"auto","x":[3326],"xaxis":"x","y":["بد"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"مرغ","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"مرغ","offsetgroup":"مرغ","orientation":"h","showlegend":true,"textposition":"auto","x":[2745],"xaxis":"x","y":["مرغ"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"common_words=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ارسال","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"ارسال","offsetgroup":"ارسال","orientation":"h","showlegend":true,"textposition":"auto"," ...

# %%
fig = px.treemap(common_sad_words, path=['common_words'], values='count',title='Tree of Most Common Words in sad comments')
fig.show()
# Out:
# <div>                            <div id="f0442ff9-72a1-4676-8b7b-c1462af64006" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0442ff9-72a1-4676-8b7b-c1462af64006")) {                    Plotly.newPlot(                        "f0442ff9-72a1-4676-8b7b-c1462af64006",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["ارسال","اصلا","بد","بودم","تحویل","ساعت","سرد","سفارش","سیب","طعم","غذا","قیمت","مرغ","مزه","نداشت","واقعا","پایین","پیتزا","کیفیت","یه"],"labels":["ارسال","اصلا","بد","بودم","تحویل","ساعت","سرد","سفارش","سیب","طعم","غذا","قیمت","مرغ","مزه","نداشت","واقعا","پایین","پیتزا","کیفیت","یه"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[2577,4628,3326,1949,2070,1740,4056,6301,2049,1898,7339,1724,2745,2098,2199,3357,1839,3997,6379,2171],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{" ...

# %%
tokens_chain = chain.from_iterable(train_df['tokens'])

# Generate bigrams
bigrams = nltk.ngrams(tokens_chain, 2)

# Use a Counter for efficient counting
bigram_counts = nltk.FreqDist(bigrams)

# Get the 20 most common bigrams
bigrams_series = pd.Series(dict(bigram_counts.most_common(20)))

bigrams_series.sort_values().plot.barh(color='blue', width=.9, figsize=(12, 8))
plt.title('20 Most Frequently Occurring Bigrams')
plt.show()
